# %% [markdown]
# # seq2seq - nmt

# %%
from collections import Counter
from datetime import datetime
import pickle
import re

import jieba
from nltk.stem.porter import PorterStemmer
from nltk.translate.bleu_score import corpus_bleu
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf  # 1.0.1
from tensorflow.python.ops import variable_scope

from data_helpers import (buckets, _PAD, _GO, _EOS, _UNK, _PAD_ID, _GO_ID, _EOS_ID, _UNK_ID)

# %matplotlib inline
# %load_ext watermark
# %watermark -p tensorflow,numpy -v -m

# %% [markdown]
# ## 模型参数

# %%
local_test = False

if local_test:
    cell_size = 10 
    num_layers = 2  # rnn cell 层数
    embedding_size = 10 
    num_sampled = 300 
else:
    cell_size = 100
    num_layers = 2  # rnn cell 层数
    embedding_size = 100
    num_sampled = 500

# %% [markdown]
# ## 加载处理好的语料和词表

# %%
with open('^data/data_13w.pkl', 'rb') as f:
    encoder_data, decoder_data, encoder_data_test, decoder_data_test = pickle.load(f)

with open('^data/vocab_13w.pkl', 'rb') as f:
    vocab_enc, vocab_dec = pickle.load(f)

data_sizes = [len(encoder_data[i]) for i in range(len(buckets))]
data_sizes_dec = [len(decoder_data[i]) for i in range(len(buckets))]
assert data_sizes == data_sizes_dec

data_sizes_test = [len(encoder_data_test[i]) for i in range(len(buckets))]
data_sizes_dec_test = [len(decoder_data_test[i]) for i in range(len(buckets))]
assert data_sizes_test == data_sizes_dec_test

print(data_sizes)
print(data_sizes_test)
# Out:
# [59648, 71510]
# [2903, 3160]

# %%
num_encoder_symbols = len(vocab_enc)
num_decoder_symbols = len(vocab_dec)
num_encoder_symbols, num_decoder_symbols
# Out:
# (7655, 10340)

# %% [markdown]
# ## 定义 RNN cell

# %%
tf.reset_default_graph()

def single_cell():
    return tf.contrib.rnn.GRUCell(cell_size)
cell = single_cell()
if num_layers > 1:
    cell = tf.contrib.rnn.MultiRNNCell([single_cell() for _ in range(num_layers)])

# %% [markdown]
# ## 创建 placeholders
#
# 注意在 bucketing 时, decoder inputs 已经做了首尾的 token: GO 和 EOS.

# %%
max_encoder_length, max_decoder_length = buckets[-1]

encoder_placeholders = [
    tf.placeholder(tf.int32, shape=[None], name="encoder_%d" % i)
    for i in range(max_encoder_length)]
decoder_placeholders = [
    tf.placeholder(tf.int32, shape=[None], name="decoder_%d" % i)
    for i in range(max_decoder_length)]
target_placeholders = [
    tf.placeholder(tf.int32, shape=[None], name="target_%d" % i)
    for i in range(max_decoder_length)]
target_weights_placeholders = [
    tf.placeholder(tf.float32, shape=[None], name="decoder_weight_%d" % i)
    for i in range(max_decoder_length)]

# %% [markdown]
# ##  `model_with_buckets` 构建模型
#
# 注: tf 1.0.1 ok. tf 1.1.0 接口有变, 会报错.

# %%
def seq2seq_f(encoder_placeholders, decoder_placeholders, do_decode):
    # 可以在这里设置不同的 seq2seq 接口, 比如 embedding_attention_seq2seq
    return tf.contrib.legacy_seq2seq.embedding_attention_seq2seq(
        encoder_placeholders,
        decoder_placeholders,
        cell,
        num_encoder_symbols=num_encoder_symbols,
        num_decoder_symbols=num_decoder_symbols,
        embedding_size=embedding_size,
        output_projection=output_projection,
        feed_previous=do_decode)

def sampled_loss(labels, logits):
    labels = tf.reshape(labels, [-1, 1])
    return tf.nn.sampled_softmax_loss(
        weights=softmax_w_t,
        biases=softmax_b,
        labels=labels,
        inputs=logits,
        num_sampled=num_sampled,
        num_classes=num_decoder_symbols)

softmax_w_t = tf.get_variable("proj_w", [num_decoder_symbols, cell_size], dtype=tf.float32)
softmax_w = tf.transpose(softmax_w_t)
softmax_b = tf.get_variable("proj_b", [num_decoder_symbols], dtype=tf.float32)
output_projection = (softmax_w, softmax_b)

outputs, losses = tf.contrib.legacy_seq2seq.model_with_buckets(
    encoder_placeholders, decoder_placeholders, target_placeholders,
    target_weights_placeholders, buckets, lambda x, y: seq2seq_f(x, y, False),
    softmax_loss_function=sampled_loss)

# %% [markdown]
# ## 准备 feed 数据
#
# 注意 embedding_rnn_seq2seq 接收的 encoder_inputs 形状为 `A list of 1D int32 Tensors of shape [batch_size]`. 为此, 可以用 `list(zip(*lst))` 来对 nested list 进行"转置", 得到需要的形状.

# %%
def left_shift(decoder_inputs):
    """generate targets grom decoder_inputs"""
    return [list(input_[1:]) + [_PAD_ID] for input_ in decoder_inputs]

def get_bucket_inputs(encoder_data, decoder_data, bucket_id):
    encoder_inputs = encoder_data[bucket_id]
    decoder_inputs = decoder_data[bucket_id]
    return (encoder_inputs, decoder_inputs)

def get_batch_inputs(encoder_data, decoder_data, bucket_id, batch_start, batch_size):
    encoder_inputs = encoder_data[bucket_id][batch_start : batch_start+batch_size]
    decoder_inputs = decoder_data[bucket_id][batch_start : batch_start+batch_size]
    return (encoder_inputs, decoder_inputs)

def generate_feed_dict(inputs_tuple, encoder_size, decoder_size):
    """对 inputs 做转置, 并喂给 placeholder 列表, 得到 feed_dict"""
    encoder_inputs, decoder_inputs = inputs_tuple
    encoder_inputs = list(zip(*encoder_inputs))
    target_inputs = list(zip(*left_shift(decoder_inputs)))
    decoder_inputs = list(zip(*decoder_inputs)) 
    
    feed_dict = dict()
    # Prepare input data
    for i in range(encoder_size):
        # 这里用 placeholder 或者 placeholder.name 都可以
        feed_dict[encoder_placeholders[i].name] = np.asarray(encoder_inputs[i], dtype=int)
    for i in range(decoder_size):
        feed_dict[decoder_placeholders[i].name] = np.asarray(decoder_inputs[i], dtype=int)
        feed_dict[target_placeholders[i].name] = np.asarray(target_inputs[i], dtype=int)        
        # 这里使用 weights 把 <PAD> 的损失屏蔽了
        feed_dict[target_weights_placeholders[i].name] = np.asarray(
            [float(idx != _PAD_ID) for idx in target_inputs[i]], dtype=float)
    return feed_dict

# %% [markdown]
# ## 训练

# %%
# 训练相关参数
epochs = 300
print_loss_every = 5
learning_rate = 0.1
batch_size = 50

# 把不同 bucket 的 loss 分别传给 optimizer, 得到不同的 train_step.
train_steps = [tf.train.AdagradOptimizer(learning_rate).minimize(losses[i]) 
               for i in range(len(buckets))]

sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
# Training
try:
    print('{:14}'.format('Time') +
          ' Epoch ' +
          ' '.join(['bucket-{}'.format(i) for i in range(len(buckets))]))
    for i in range(epochs):
        if i % print_loss_every == 0:
            print('\n{} {: 4d}'.format(str(datetime.now())[5:-7], 
                                       i), end=' ')

        for bucket_id in range(len(buckets)):
            cur_data_size = data_sizes[bucket_id]
            if cur_data_size == 0:
                continue  # 某个 bucket 为空的特殊情形
            encoder_size, decoder_size = buckets[bucket_id]
            
            # 输出 loss 过程信息
            if i % print_loss_every == 0:
                bucket_inputs = get_bucket_inputs(encoder_data, decoder_data, bucket_id)
                bucket_feed = generate_feed_dict(bucket_inputs, encoder_size, decoder_size)
                loss_val = sess.run(losses[bucket_id], feed_dict=bucket_feed)
                print('{: 8.4f}'.format(loss_val), end=' ')
            
            # 训练
            for batch_start in range(0, cur_data_size, batch_size):
                batch_inputs = get_batch_inputs(
                    encoder_data, decoder_data, bucket_id, batch_start, batch_size)
                batch_feed = generate_feed_dict(batch_inputs, encoder_size, decoder_size)
                sess.run(train_steps[bucket_id], feed_dict=batch_feed)
except KeyboardInterrupt:
    print('\nKeyboardInterrupt')

# plt.plot(range(0, i, print_loss_every), loss_history);
# Out:
# Time           Epoch bucket-0 bucket-1
#
# 05-16 16:39:37    0   8.2900   5.1339
# 05-16 17:03:02    5   1.9113   2.6406
# 05-16 17:26:21   10   1.3782   2.0690
# 05-16 17:49:26   15   1.1184   1.8494
# 05-16 18:12:31   20   1.0265   1.7606
# 05-16 18:35:38   25   0.9266   1.6591
# 05-16 18:58:52   30   0.9358   1.6388
# 05-16 19:22:06   35   0.8697   1.6019
# 05-16 19:45:12   40   0.8602   1.5540
# 05-16 20:08:29   45   0.8384   1.5853
# 05-16 20:31:33   50   0.8289   1.5236
# 05-16 20:54:39   55   0.8224   1.5609
# 05-16 21:17:43   60   0.8483   1.4962
# 05-16 21:40:44   65   0.8166   1.5114
# 05-16 22:03:44   70   0.8236   1.5825
# 05-16 22:26:44   75   0.8087   1.5266
# 05-16 22:49:52   80   0.8049   1.5184
# 05-16 23:13:03   85   0.7548   1.5002
# 05-16 23:36:03   90   0.7928   1.5417
# 05-16 23:59:11   95   0.7958   1.5213
# KeyboardInterrupt

# %% [markdown]
# 用 `embedding_attention_seq2seq` 替换 `embedding_rnn_seq2seq` 后, 单步计算时间变长, 但 cost 也下降得更快.

# %%
# 保存模型参数
saver = tf.train.Saver()
saver.save(sess, "./^tmp/model_v04.ckpt")
# Out:
# './tmp/model_v04.ckpt'

# %% [markdown]
# ## 测试
#
# decoding 过程中, 因为 feed_previous 为 true, 所以 `decoder_inputs` 只用到第一个元素, 后面的都不需要.

# %%
# 读取模型参数
saver = tf.train.Saver()
sess = tf.Session()
saver.restore(sess, "./^tmp/model_v04.ckpt")

# %%
num_examples_to_print = 50

def cut_at_eos(sentence):
    if _EOS in sentence:        
        return sentence[:sentence.index(_EOS)]
    else:
        return sentence

def no_prepending_pad(sentence):
    for i in range(len(sentence)):
        if sentence[i] != _PAD:
            return sentence[i:]

list_of_references = []
hypotheses = []

with variable_scope.variable_scope(variable_scope.get_variable_scope(), reuse=True):
    outputs, losses = tf.contrib.legacy_seq2seq.model_with_buckets(
        encoder_placeholders, decoder_placeholders, target_placeholders,
        target_weights_placeholders, buckets, lambda x, y: seq2seq_f(x, y, True),
        softmax_loss_function=sampled_loss)
    
    if output_projection is not None:
        for bucket_id in range(len(buckets)):
            outputs[bucket_id] = [
                tf.matmul(output, output_projection[0]) + output_projection[1]
                for output in outputs[bucket_id]]

    for bucket_id in range(len(buckets)):
        print('\n** bucket {}'.format(bucket_id))
        cur_data_size = data_sizes_test[bucket_id]
        print('test examples: {}'.format(cur_data_size))
        if cur_data_size == 0:
            continue  # 某个 bucket 为空的特殊情形

        encoder_size, decoder_size = buckets[bucket_id]
        bucket_inputs_test = get_bucket_inputs(encoder_data_test, decoder_data_test, bucket_id)
        bucket_feed = generate_feed_dict(bucket_inputs_test, encoder_size, decoder_size)

        loss_val = sess.run(losses[bucket_id], feed_dict=bucket_feed)
        print('loss = {: 8.4f}'.format(loss_val))
        
        output_bucket = np.zeros((cur_data_size, decoder_size), dtype=int)  
        # output_bucket 用于记录当前bucket输出值, 形状是 outputs 的"转置"
    
        for i in range(decoder_size):
            prob = outputs[bucket_id][i]  # 第i个词的概率输出
            output_bucket[:, i] = np.argmax(sess.run(prob, feed_dict=bucket_feed), axis=1)
        
        for j in range(cur_data_size):
            sen = [vocab_dec[output_bucket[j, k]] for k in range(decoder_size)]
            input_ = [vocab_enc[i] for i in encoder_data_test[bucket_id][j]]
            target_ = [vocab_dec[i] for i in decoder_data_test[bucket_id][j][1:]]
            input_ = no_prepending_pad(input_)
            sen = cut_at_eos(sen)
            target_ = cut_at_eos(target_)
            
            list_of_references.append([target_])
            hypotheses.append(sen)

            if j <= num_examples_to_print:  # 只打印前几个例子
                print(' input: ', ' '.join(input_))
                print('output: ', ' '.join(sen))
                print('target: ', ' '.join(target_))
                print()
# Out:
# ** bucket 0
# test examples: 2903
# loss =   5.3535
#  input:  II . organ OF the meet
# output:  二 . 会议 安排 . 1 - 11 2
# target:  二 . 本次 会议 的 组织 事项
#
#  input:  through improv ocean govern ( agenda item 7 )
# output:  通过 改进 能源 的 议程 ( 议程 项目 7 )
# target:  的 实施 工作 ( 议程 项目 7 )
#
#  input:  it work should be reinforc .
# output:  在 此 方面 开始 加强 工作 应是 加强 的 。
# target:  应 设法 加强 该 协调 处 的 工作 。
#
#  input:  xii . adopt OF the report OF the meet
# output:  十二 . 通过 会议 报告
# target:  十二 . 通过 本次 会议 报告
#
#  input:  mainstream of the global programm of action
# output:  将 采取 全球 行动 方案 纳入 全球 方案
# target:  将 《 全球 行动 纲领 》 作为 主流 事项
#
#  input:  financ of the global programm of action
# output:  全球 行动 方案 的 经费 筹措
# target:  《 全球 行动 纲领 》 的 筹资
#
#  input:  for the protect OF the marin environ from
# output:  森林 及 森林 带来 森林 缔约方 的 保护 委员会
# target:  第一次 政府 间 审查会议 联席 主席 的 结论
#
#  input:  C . the strateg action plan on municip wastewat
# output:  C . 《 荒漠化 团 行动计划 》 的 行动计划
# target:  C . 城市 废水 问题 战略 行动计划
#
#  input:  In thi regard , it aim to :
# output:  在 这方面 , 其 目的 : 旨在 :
# target:  在 此 方面 , 其 目的 是 :
#
#  input:  facilit the mobil of financi resourc ;
# output:  便利 资金 的 调动 资源 ;
# target:  ( a ) 促进 调集 财力 资源 ;
#
#  input:  E . ocean and coastal govern
# output:  E . 海洋 和 库存 治理 6 - 23 3
# target:  E . 海洋 和 沿海 管理
#
#  input:  statement BY the intern council for
# output:  《 国际 基金 及 关于 国际 理事会 理事会 的
# target:  国际 地方 环境 行动 理事会 的 声明
#
#  input:  C . specif action for non-government organ
# output:  C . 非政府 组织 的 具体 行动
# target:  C . 非政府 组织 的 具体 行动
#
#  input:  discuss on the issu and on draft decis :
# output:  讨论 各项 问题 的 讨论 和 决定 草案 :
# target:  3 . 讨论 有关 议题 和 决定 草案 :
#
#  input:  iii . discuss ON the issu and ON draft decis
# output:  三 . 关于 定义 和 决定 的 问题 和 处理 的
# target:  三 . 讨论 有关 议题 和 决定 草案
#
#  input:  D . select of member of the implement committe
# output:  D . 执行 委员会 的 执行 委员会 成员
# target:  D . 推选 履行 委员会 成员
#
#  input:  J . essenti use exempt applic
# output:  J . 基本 适用 于 所 适用 的 使用 办法
# target:  J . 必要 用途 豁免 申请
#
#  input:  membership chang in the technolog and econom assess panel
# output:  技术 和 经济 评估 部门 的 变化
# target:  技术 和 经济 评估 小组 成员 的 变动
#
#  input:  IV . complianc issu consid by the implement committe
# output:  四 . 执行 委员会 根据 委员会 审议 的 问题
# target:  四 . 履行 委员会 审议 的 遵约 问题
#
#  input:  that should then pose no difficulti .
# output:  然后 , 这 也 不是 没有 任何 好处 。
# target:  这 应当 不会 有 什么 困难 。
#
#  input:  1 . open of the high-level segment :
# output:  1 . 高级别 部分 的 日期 应 部分 :
# target:  1 . 高级别 会议 部分 开幕 :
#
#  input:  3 . summari present by the assess panel .
# output:  3 . 评估 小组 的 现行 总结 。
# target:  3 . 各 评估 小组 作 概要 介绍 。
#
#  input:  E . summari present by the assess panel
# output:  E . 评估 小组 所 需 总结 .
# target:  E . 各 评估 小组 作 概要 介绍
#
#  input:  thi chemic inde constitut a hazard to the environ .
# output:  这种 化学品 对 环境 的 歧视性 不 引起 了 证明 。
# target:  这一 化学品 的确 对 环境 构成 危害 。
#
#  input:  not all administr decis were includ .
# output:  所有 行政 的 决定 包括 下列 工作 。
# target:  其中 并未 包括 所有 行政 决定 。
#
#  input:  H . present by the presid of the implement committe
# output:  H . 主席 主持 执行 委员会 主席 的 情况
# target:  H . 履行 委员会 主席 作 介绍性 发言
#
#  input:  I . statement by head of deleg
# output:  一 代表团 团长 团长 的 发言
# target:  I . 各 代表团 团长 发言
#
#  input:  the twelfth meet of the parti decid :
# output:  缔约方 会议 会议 的 一些 决定 [ 1 ] 决定 :
# target:  156 . 缔约方 第十二次 会议 决定 如下 :
#
#  input:  for basic domest need in 2001
# output:  1996 / 219 . 适用 于 2001 年 适用 的 基本
# target:  基本 需要 的 甲基 溴 生产
#
#  input:  3 . To request the technolog and econom assess panel :
# output:  3 . 请 技术 和 经济 纲领 : 小组 理事会 :
# target:  3 . 请 技术 和 经济 评估 小组 :
#
#  input:  term of offic of the implement committe and it offic
# output:  执行 委员会 及其 主席团 办事处 委员会 成员 的 任期
# target:  履行 委员会 及其 官员 的 任期
#
#  input:  approv 2000 , revis 2001 and propos 2002 budget
# output:  2000 年 2000 2001 年 2001 年 订正 概算 , 订正
# target:  2001 年 订正 预算 及 2002 年 概算
#
#  input:  meet for the promot of the protocol among non-parti
# output:  致 促进 日内瓦 持久 科学 法院 贩运 会议
# target:  旨在 非 缔约方 中 宣传 《 议定书 》 会议
#
#  input:  other ( intern ozon day )
# output:  ( 国际 对 其他 药物 的 声明 )
# target:  其他 ( 国际 臭氧 日 )
#
#  input:  grand total ( inclus of programm support cost )
# output:  总计 ( 包括 方案 支助 方案 )
# target:  总计 ( 包括 方案 支助 费用 )
#
#  input:  thi item includ assist to particip .
# output:  本 项目 包括 协助 对 与会者 的 援助 。
# target:  本 细目 包括 对 与会者 的 资助 。
#
#  input:  name of the parti 2000 UN scale of assess
# output:  2000 年 缔约方 2000 年 缔约方 会议
# target:  2000 年 联合国 会费 分摊 比例
#
#  input:  3 . discuss on the issu and on draft decis :
# output:  3 . 关于 问题 的 讨论 及 决定 草案 : 决定
# target:  3 . 讨论 有关 议题 和 决定 草案 :
#
#  input:  V . financi statement and budget for the trust fund
# output:  五 . 经费 报表 和 预算 预算
# target:  信托 基金 的 财务报表 和 预算
#
#  input:  prepar by the secretariat for meet of the parti
# output:  为 缔约方 会议 编写 筹备工作
# target:  缔约方 会议 编制 的 决定 草案
#
#  input:  statement by the execut director of unit nation environ programm ;
# output:  联合国 联合国环境规划署 执行 主任 的 发言 ;
# target:  ( b ) 联合国环境规划署 执行 主任 致词 ;
#
#  input:  the parti had identifi topic for which updat were request .
# output:  各方 已 查明 了 增订 请求 的 增订 。
# target:  缔约方 认明 了 需要 补充 更新 的 课题 。
#
#  input:  the bilater assist programm continu to grow .
# output:  双边 援助 方案 继续 越来越 免疫 。
# target:  186 . 双边 援助 方案 继续 扩大 。
#
#  input:  that work had larg come to an end .
# output:  这项 工作 在 目的 确实 普遍 普遍 认识 到 。
# target:  此项 任务 已经 大体 结束 。
#
#  input:  VI . present BY the presid OF the implement committe
# output:  六 . 执行 委员会 主席 提出 的 介绍 情况
# target:  六 . 履行 委员会 主席 的 发言
#
#  input:  vii . statement BY head OF deleg
# output:  七 . 代表 各 代表团 团长 发 了 言
# target:  七 . 各国 代表团 团长 的 发言
#
#  input:  the 13th meet of the parti decid :
# output:  227 . 缔约方 会议 的 会议 以后 了 了 决定 :
# target:  230 . 缔约方 第十三次 会议 决定 如下 :
#
#  input:  ( d ) approv countri programm ;
# output:  ( d ) 批准 的 核准 国别 方案 ;
# target:  ( d ) 经 核准 的 国家 方案 ;
#
#  input:  that in so do , the secretariat should :
# output:  言 , 应 在 我国 境内 作出 下述 情况 :
# target:  2 . 在 此项工作 中 , 秘书处 应 :
#
#  input:  other repres concur in that understand .
# output:  其他 代表 在 银行 派 同意 了 这一 事 。
# target:  其他 一些 代表 对 此种 理解 表示 赞同 。
#
#  input:  other ( intern ozon day )
# output:  ( 国际 对 其他 药物 的 声明 )
# target:  其他 ( 国际 臭氧 日 )
#
#
# ** bucket 1
# test examples: 3160
# loss =   6.5161
#  input:  role of civil societi and local govern ;
# output:  民间 设施 和 当地 政府 的 作用 ;
# target:  ( d ) 民间 社会 和 地方 政府 的 作用 ;
#
#  input:  IV . review OF accomplish IN the implement OF the
# output:  四 、 审查 《 京都 境内 的 成果 增进 1990 年 3 - 14
# target:  四 . 审查 《 全球 行动 纲领 》 1995 - 2001 年
#
#  input:  the item wa introduc by the coordin of the coordin offic .
# output:  协调 方案 下 介绍 了 了 这个 项目 。
# target:  36 . 协调 处 的 协调员 介绍 了 这 一 议程 项目 。
#
#  input:  indic cost ( agenda item 6 )
# output:  关于 指示 的 指示 ( 议程 项目 6 )
# target:  拟议 工作 方案 及其 所涉 指示 性 费用 ( 议程 项目 6 )
#
#  input:  nine region programm of action had been or were be develop .
# output:  已 拟订 了 该 行动 纲领 规划 。
# target:  九个 区域 行动 纲领 已经 完成 或 正在 编写 之中 。
#
#  input:  voluntari agreement had been drawn up , as had nation plan of action .
# output:  已 说 , 自愿 协议 是 国家 行动计划 。
# target:  国家 行动计划 和 自愿 协定 都 已 拟定 。
#
#  input:  experi wa avail , but need to be dissemin wide .
# output:  这些 经验 获得 了 可 达到 的 经验 。
# target:  已经 积累 了 一些 经验 , 但 需要 广泛 加以 推广 。
#
#  input:  vii . improv the implement OF the global programm OF action
# output:  七 、 改进 全球 行动 方案 的 执行
# target:  七 . 通过 改善 海洋 管理 来 改进 《 全球 行动 纲领 》
#
#  input:  land-bas activ ( agenda item 8 )
# output:  《 次 组织 行动 》 ( 议程 项目 8 ) 项目
# target:  建立 伙伴关系 和 筹措 资金 ( 议程 项目 8 )
#
#  input:  financ wa the other side of the equat .
# output:  81 . 资金 是 当今 界定 的 其它 的 办法 。
# target:  供资 问题 则 涉及 这一 事项 的 另外 一半 。
#
#  input:  suffici fund should be rais to allow the programm of work to go forward .
# output:  应 更加 足够 的 资助 来 地 增加 该 方案 的 工作 方案 。
# target:  需要 筹集 充足 的 资金 以便 使 工作 方案 进行 下去 。
#
#  input:  particular emphasi wa place on the strateg action on municip wastewat .
# output:  着眼于 关于 迅速 国家 东帝汶 的 社会 管理 的 战略 。
# target:  与会者 特别强调 城市 废水 的 战略 行动 。
#
#  input:  the offic ' s move from plan to action wa welcom .
# output:  监督 厅 对 附属 的 行动 作出 的 检查 值得 得到 行动 。
# target:  协调 办公室 从 计划 阶段 到 行动 阶段 的 转变 受到 欢迎 。
#
#  input:  the organ of coordin meet among region sea programm wa welcom .
# output:  欢迎 各 区域 各 基金 之间 协调 协调会议 的 安排 。
# target:  在 区域 海洋 方案 之间 组织 召开 协调会议 受到 欢迎 。
#
#  input:  improv in govern should be at a level appropri to the problem .
# output:  应 在 这个 问题 中 , 也 应 改进 政府 的 改进 。
# target:  管理 上 的 改进 水平 应该 与 问题 的 程度 相一致 。
#
#  input:  No other busi wa rais for discuss .
# output:  对 进行 了 其他 的 其他 杂项 以外 的 其他 组织 。
# target:  124 . 没有 提出 任何 供 讨论 的 问题 。
#
#  input:  montreal declar ON the protect OF the marin environ from land-bas activ
# output:  《 公约 》 关于 大会 活动 的 保护 宣言 》
# target:  关于 保护 海洋环境 免受 陆地 活动 影响 的 蒙特利尔 宣言
#
#  input:  ( i ) In the implement of the global programm of action ;
# output:  ㈠ 实施 《 全球 行动 方案 纲领 》 ;
# target:  ( i ) 执行 《 全球 行动 纲领 》 方面 ;
#
#  input:  ( ii ) with other relev region organ ;
# output:  ( 二 ) 与 其他 有关 组织 的 组织 ;
# target:  ( ii ) 与 其他 相关 的 区域 组织 ;
#
#  input:  We request that the next global ministeri environ forum endors thi outcom .
# output:  我们 请 请 全世界 信任 环境 部长 来 成果 处理 这一 成果 。
# target:  我们 提请 下 一次 全球 部长级 环境 论坛 核可 这 一 结果 。
#
#  input:  A . accomplish of the global programm of action
# output:  A . 全球 行动 纲领 中 的 总结
# target:  A . 《 全球 行动 纲领 》 取得 的 成就
#
#  input:  consider of the impact of small industri on sewag system ;
# output:  审议 小 工业 不 容忍 制度 的 影响 ;
# target:  ( c ) 考虑 建立 处理 污水 系统 的 小型 工业 ;
#
#  input:  further involv the privat sector and civil societi ;
# output:  对 私营部门 和 民间 社会 参与 进一步 参与 的 问题 ;
# target:  ( b ) 促使 私营部门 和 民众 社会 的 进一步 参与 ;
#
#  input:  strengthen cooper with unit nation agenc .
# output:  加强 联合国 机构 的 合作 。
# target:  ( e ) 加强 和 联合国 各 机构 的 合作 。
#
#  input:  the cost-effect of initi within the programm of work should also be analys .
# output:  还应 分析 该 方案 的 基础 工作 安排 。
# target:  还 应该 分析 工作 方案 内 各项 举措 的 成本 效益 。
#
#  input:  they are a fundament pillar for improv coastal and ocean govern .
# output:  他们 是 提高 一个 公司 的 一个 治理 和 海洋 的 机会 。
# target:  它们 是 改进 沿海 和 海洋 管理 的 基本 支柱 。
#
#  input:  F . financ the global programm of action
# output:  F . 为 精神 方案 全球 全球 全球 方案 经费 13 - 24 4
# target:  F . 为 实施 《 全球 行动 纲领 》 筹措 资金
#
#  input:  fund partner includ gef and govern of the unit state of america and sweden .
# output:  资金 包括 包括 美国 和 瑞典 政府 的 政策 。
# target:  筹措 资金 的 伙伴 包括 全球 环境 基金 和 美利坚合众国 与 瑞典政府 。
#
#  input:  extern fund is need for mani plan activ . mediterranean
# output:  需要 许多 计划 的 外部 支助 活动 : 谈判 进行
# target:  需要 为 许多 业已 作出 规划 的 活动 提供 外来 资金 。
#
#  input:  It is expect to enter into forc in 2002 .
# output:  预期 它 将 于 2002 年 生效 。
# target:  预期 该 议定书 将 于 2002 年 开始 生效 。
#
#  input:  the request wa includ in the amend agenda as item 3 ( l ) .
# output:  该 请求 已 列入 修正 ( ) 项目 ( ) ( ) 。
# target:  这一 要求 已 作为 项目 3 ( l ) 列入 修正 议程 。
#
#  input:  statement by the execut director of the unit nation environ programm ( unep ) .
# output:  联合国环境规划署 ( 环境 ) 执行 主任 的 发言
# target:  联合国环境规划署 ( 环境署 ) 执行 主任 致词 。
#
#  input:  member of the execut committe of the multilater fund ;
# output:  环境 基金 执行 委员会 成员 ;
# target:  ( ii ) 多边 基金 执行 委员会 成员 ; 和
#
#  input:  complianc issu consid by the implement committe .
# output:  1 . 遵约 委员会 审议 的 问题 构成 执行 委员会 。
# target:  4 . 经 履行 委员会 审议 的 遵守 情事 事项 。
#
#  input:  financi statement and budget for the trust fund for the montreal protocol .
# output:  《 蒙特利尔 议定书 》 的 财务 和 预算 财务报表 。
# target:  5 . 《 蒙特利尔 议定书 》 信托 基金 的 财务报告 和 预算 。
#
#  input:  He propos that the technolog and econom assess panel should studi the issu .
# output:  他 建议 技术 和 经济 援助 补充 小组 应当 补充 要点 。
# target:  他 提议 由 技术 和 经济 评估 小组 研究 这一 问题 。
#
#  input:  mani repres emphas their opposit to the propos submit by the european commun .
# output:  许多 代表 们 们 们 表示 强调 向 欧洲共同体 提出 的 提案 。
# target:  25 . 许多 代表 强调 , 他们 反对 欧洲共同体 提交 的 提案 。
#
#  input:  the plenari agre to recommend the draft decis as amend by the contact group .
# output:  全体会议 同意 后 就 修正 后 作出 的 决定 草案 。
# target:  全体会议 商定 建议 通过 经由 接触 小组 修正 的 该 决定 草案 。
#
#  input:  E . select of member of the execut committe of the multilater fund
# output:  E . 多边 基金 环境 委员会 的 成员 选定 选定 的 选定 情况
# target:  E . 推选 多边 基金 执行 委员会 成员
#
#  input:  the decis wa recommend to the high-level segment , subject to updat .
# output:  决定 的 决定 建议 以 高级别 会议 上 更新 。
# target:  建议 高级别 会议 部分 审议 该项 决定 , 但须 予以 增订 。
#
#  input:  He offer to work close with the ozon secretariat to resolv the problem .
# output:  他 与 秘书处 做出 决心 与 解决 这个 问题 的 工作 。
# target:  他 主动 提出 与 臭氧 秘书处 密切合作 解决 这一 问题 。
#
#  input:  M . request by kyrgyzstan to be classifi as a parti oper under articl 5
# output:  M . 对 贸发 会议 的 联合 缔约方 作为 一项 未决 现实 之下 的
# target:  M . 吉尔吉斯斯坦 请求 被 列为 按 《 蒙特利尔 议定书 》
#
#  input:  coordin between the ozon secretariat and the secretariat of the multilater fund
# output:  《 秘书处 秘书处 和 秘书处 秘书处 协调 "
# target:  臭氧 秘书处 与 多边 基金 秘书处 之间 的 协调
#
#  input:  V . financi statement and budget for the trust fund for the montreal protocol
# output:  五 、 蒙特利尔 议定书 信托 基金 和 预算 .
# target:  五 . 《 蒙特利尔 议定书 》 信托 基金 的 财务报告 和 预算
#
#  input:  He also express appreci to all the donor countri that had provid support .
# output:  他 表示 赞赏 捐助国 支持 提供 提供 的 支持 。
# target:  他 还 对 所有 提供 了 支助 的 捐助国 表示 赞赏 。
#
#  input:  B . elect of the offic of the twelfth meet of the parti
# output:  B . 选举 缔约方 会议 的 会议
# target:  B . 选举 缔约方 第十二次 会议 的 主席团 成员
#
#  input:  He focus on two question pose by the parti .
# output:  在 本 缔约方 , 有 了 关于 有关 当事 缔约方 的 问题 。
# target:  他 着重 探讨 了 缔约方 所 提出 的 以下 两个 问题 。
#
#  input:  the co-chair gave exampl in the three class .
# output:  这次 期间 的 控告 在 下面 三项 上 作为 三项 上 。
# target:  该 联席 主席 分别 列举 了 这 三个 类别 中 的 实例 。
#
#  input:  F . present by the repres of unit nation agenc and the world bank
# output:  F . 联合国 机构 和 世界银行 及其 世界银行 的 会议 .
# target:  F . 联合国 各 机构 和 世界银行 的 代表作 介绍性 发言
#
#  input:  the project were take place in 71 countri , in all geograph region .
# output:  该 项目 在 计划 所有 地域 区域 进行 了 一些 区域 。
# target:  这些 项目 正在 所有 地理 区域 的 71 个 国家 中 执行 。
#
#  input:  most substant decis taken by the committe were refer to in the report .
# output:  委员会 所 收到 的 实质性 决定 就是 提到 该 报告 。
# target:  报告 中 提到 委员会 所作 的 最 具有 实质性 的 决定 。

# %% [markdown]
# 训练时的 loss, 是在 feed_previous 为假时算得的.
# 用同样的模型参数, 在 decode 时, 因为 feed_previous 为真, 算得的 loss 会大很多.

# %%
bleu = corpus_bleu(list_of_references, hypotheses)
print('BLEU score: {:.4f}'.format(bleu))
# Out:
# BLEU score: 0.2820

# %% [markdown]
# ## ChangeLog
#
# * v0.0
#   * 读入 6w 行, 筛选后 data sizes = 5315, 9982, 13714, 12743
#   * buckets = [(7, 7), (15, 15), (25, 25), (35, 35)]
#   * 词表大小: 24468 22505 (min freq = 2, 2)
#   * train cost: 0.4598   0.8442   2.2040   2.7353  (步长=1, 训练时间 4h)
#   * test cost: 6.1954, 9.2254, 10.3698, 10.5111
# * v0.1
#   * 读入 80w 行, 筛选后 data sizes = 28860, 44106
#   * buckets = [(11, 11), (15, 15)]
#   * 词表大小: 5402 6815 (min freq = 7, 8)
#   * train cost: 1.1266   2.2595 (步长=1, 训练时间 7h) -> 步长取大了
#   * test cost: 5.7415, 6.9102
# * v0.2
#   * 改用 `embedding_attention_seq2seq`
#   * 步长: 0.3
#   * train cost: 1.0095   2.7291 (训练时间 6.5h)
#   * test cost: 5.0621, 8.4917
# * v0.3
#   * 步长: 0.1
#   * train cost: 0.9406   1.8938 (time = 2.5 h)
#   * test cost: 4.5514, 7.4168
#     * feed_previous 改为 True (仅用于查看检验), test cost: 2.1128, 3.4633
#   * BLEU: 0.2112
# * v0.4
#   * 有效数据加倍 -> [59648, 71510]
#   * train cost: 0.7958   1.5213 (time = 7h)
#   * test cost: 5.3535, 6.5161
#   * BLEU: 0.2820
